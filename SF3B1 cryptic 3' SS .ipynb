# %% [markdown]
# The python code is also in this folder.

# %%
setwd('~/bme/jupyter_data')
wtbias = read.table('bias_dist_wt_w5m30')
mtbias = read.table('bias_dist_w5m30_k700e')
plot(mtbias, type='l')
points(wtbias, type='l', col='blue')
# Out:
#      V1 V2
# plot without title
